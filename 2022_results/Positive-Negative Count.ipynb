# %%
import pandas as pd
import numpy as np

# %%
GC_female = pd.read_csv("./Selected Features/importances_GC_F.csv")
GC_male = pd.read_csv("./Selected Features/importances_GC_M.csv")
GC_hemi_male = pd.read_csv("./Selected Features/importances_GC_hemi_M.csv")
GC_homo_female = pd.read_csv("./Selected Features/importances_GC_homo_F.csv")
GC_homo_male = pd.read_csv("./Selected Features/importances_GC_homo_M.csv")
rare_AD_female = pd.read_csv("./Selected Features/importances_rare_AD_F.csv")
rare_AD_male = pd.read_csv("./Selected Features/importances_rare_AD_M.csv")
rare_AR_female = pd.read_csv("./Selected Features/importances_rare_AR_F.csv")
rare_AR_male = pd.read_csv("./Selected Features/importances_rare_AR_M.csv")
rare_hemi_male = pd.read_csv("./Selected Features/importances_rare_hemi_M.csv")

# %%
positive = GC_female[GC_female['importance'] >= 0].shape[0]
negative = GC_female[GC_female['importance'] < 0].shape[0]

print ("GC FEMALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(GC_female.shape[0],"\tTOTAL genes")
print("\n")

positive = GC_male[GC_male['importance'] >= 0].shape[0]
negative = GC_male[GC_male['importance'] < 0].shape[0]

print ("GC MALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(GC_male.shape[0],"\tTOTAL genes")
print("\n")

positive = GC_hemi_male[GC_hemi_male['importance'] >= 0].shape[0]
negative = GC_hemi_male[GC_hemi_male['importance'] < 0].shape[0]

print ("GC HEMI MALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(GC_hemi_male.shape[0],"\tTOTAL genes")
print("\n")

positive = GC_homo_female[GC_homo_female['importance'] >= 0].shape[0]
negative = GC_homo_female[GC_homo_female['importance'] < 0].shape[0]

print ("GC HOMO FEMALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(GC_homo_female.shape[0],"\tTOTAL genes")
print("\n")

positive = GC_homo_male[GC_homo_male['importance'] >= 0].shape[0]
negative = GC_homo_male[GC_homo_male['importance'] < 0].shape[0]

print ("GC HOMO MALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(GC_homo_male.shape[0],"\tTOTAL genes")
print("\n")

positive = rare_AD_female[rare_AD_female['importance'] >= 0].shape[0]
negative = rare_AD_female[rare_AD_female['importance'] < 0].shape[0]

print ("rare AD FEMALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(rare_AD_female.shape[0],"\tTOTAL genes")
print("\n")

positive = rare_AD_male[rare_AD_male['importance'] >= 0].shape[0]
negative = rare_AD_male[rare_AD_male['importance'] < 0].shape[0]

print ("rare AD MALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(rare_AD_male.shape[0],"\tTOTAL genes")
print("\n")

positive = rare_AR_female[rare_AR_female['importance'] >= 0].shape[0]
negative = rare_AR_female[rare_AR_female['importance'] < 0].shape[0]

print ("rare AR FEMALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(rare_AR_female.shape[0],"\tTOTAL genes")
print("\n")

positive = rare_AR_male[rare_AR_male['importance'] >= 0].shape[0]
negative = rare_AR_male[rare_AR_male['importance'] < 0].shape[0]

print ("rare AR MALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(rare_AR_male.shape[0],"\tTOTAL genes")
print("\n")

positive = rare_hemi_male[rare_hemi_male['importance'] >= 0].shape[0]
negative = rare_hemi_male[rare_hemi_male['importance'] < 0].shape[0]

print ("rare HEMI MALES:")
print(positive,"\tPOSITIVE genes")
print(negative,"\tNEGATIVE genes")
print("-------------------------")
print(rare_hemi_male.shape[0],"\tTOTAL genes")
print("\n")
# Out:
# GC FEMALES:
# 23 	POSITIVE genes
# 21 	NEGATIVE genes
# -------------------------
# 44 	TOTAL genes
#
#
# GC MALES:
# 52 	POSITIVE genes
# 60 	NEGATIVE genes
# -------------------------
# 112 	TOTAL genes
#
#
# GC HEMI MALES:
# 15 	POSITIVE genes
# 16 	NEGATIVE genes
# -------------------------
# 31 	TOTAL genes
#
#
# GC HOMO FEMALES:
# 546 	POSITIVE genes
# 555 	NEGATIVE genes
# -------------------------
# 1101 	TOTAL genes
#
#
# GC HOMO MALES:
# 3 	POSITIVE genes
# 8 	NEGATIVE genes
# -------------------------
# 11 	TOTAL genes
#
#
# rare AD FEMALES:
# 28 	POSITIVE genes
# 8 	NEGATIVE genes
# -------------------------
# 36 	TOTAL genes
#
#
# rare AD MALES:
# 4 	POSITIVE genes
# 8 	NEGATIVE genes
# -------------------------
# 12 	TOTAL genes
#
#
# rare AR FEMALES:
# 5 	POSITIVE genes
# 3 	NEGATIVE genes
# -------------------------
# 8 	TOTAL genes
#
#
# rare AR MALES:
# 35 	POSITIVE genes
# 35 	NEGATIVE genes
# -------------------------
# 70 	TOTAL genes
#
#
# rare HEMI MALES:
# ...
